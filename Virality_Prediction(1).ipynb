# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article  
import csv 
import pandas as pd
import numpy as np

# %%
pip install newspaper3k
# Out:
# Collecting newspaper3k
#   Downloading https://files.pythonhosted.org/packages/d7/b9/51afecb35bb61b188a4b44868001de348a0e8134b4dfa00ffc191567c4b9/newspaper3k-0.2.8-py3-none-any.whl (211kB)
#      |████████████████████████████████| 215kB 3.4MB/s
# Collecting tldextract>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/fd/0e/9ab599d6e78f0340bb1d1e28ddeacb38c8bb7f91a1b0eae9a24e9603782f/tldextract-2.2.2-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 5.3MB/s
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.6.3)
# Collecting feedfinder2>=0.0.4
#   Downloading https://files.pythonhosted.org/packages/35/82/1251fefec3bb4b03fd966c7e7f7a41c9fc2bb00d823a34c13f847fd61406/feedfinder2-0.0.4.tar.gz
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.13)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.2.6)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (7.0.0)
# Collecting cssselect>=0.9.2
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Collecting tinysegmenter==0.3
#   Downloading https://files.pythonhosted.org/packages/17/82/86982e4b6d16e4febc79c2a1d68ee3b707e8a020c5d2bc4af8052d0f136a/tinysegmenter-0.3.tar.gz
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.21.0)
# Collecting feedparser>=5.2.1
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
#      |████████████████████████████████| 194kB 9.7MB/s
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.2.5)
# Collecting jieba3k>=0.35.1
#   Downloading https://files.pythonhosted.org/packages/a9/cb/2c8332bcdc14d33b0bedd18ae0a4981a069c3513e445120da3c3f23a8aaa/jieba3k-0.35.1.zip (7.4MB)
#      |████████████████████████████████| 7.4MB 10.5MB/s
# Requirement already satisfied: idna in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (2.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (46.1.3)
# Collecting requests-file>=1.4
#   Downloading https://files.pythonhosted.org/packages/77/86/cdb5e8eaed90796aa83a6d9f75cfbd37af553c47a291cd47bc410ef9bdb2/requests_file-1.5.1-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Building wheels for collected packages: feedfinder2, tinysegmenter, feedparser, jieba3k
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp36-none-any.whl size=3357 sha256=58f3b3ad672711699cebd0ba52c3de9c5ab7ded479fa174e60f2eddf4cadd09b
#   Stored in directory: /root/.cache/pip/wheels/de/03/ca/778e3a7a627e3d98836cc890e7cb40c7575424cfd3340f40ed
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp36-none-any.whl size=13539 sha256=53da0702ed9ee6ee4e8ad174fb23dd4b181c99abf7f271783d7eac3d48e900d3
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=38cb062bbfc7e0987ae4beca111c3a6e76d73bb0293af8a5e313c8964291b962
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp36-none-any.whl size=7398406 sha256=b87cd1cc433498ed2a3d0014d8bfaef2c4a000ef0038c16ea6935e2a29911573
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# Successfully built feedfinder2 tinysegmenter feedparser jieba3k
# Installing collected packages: requests-file, tldextract, feedfinder2, cssselect, tinysegmenter, feedparser, jieba3k, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-5.2.1 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 tinysegmenter-0.3 tldextract-2.2.2

# %%
url = "https://aajtak.intoday.in/"
from bs4 import BeautifulSoup
import urllib.request as urllib2
import re

html_page = urllib2.urlopen("https://aajtak.intoday.in/")
soup = BeautifulSoup(html_page)
links = []

for link in soup.findAll('a'):
    if not link.get('href').startswith('http'):
      link = url + link.get('href')
      links.append(link)
print(links)
# Out:
# ['https://aajtak.intoday.in//moviemasala', 'https://aajtak.intoday.in//news-on-films.html', 'https://aajtak.intoday.in//new-trailer-and-new-songs-of-upcoming-hindi-films-of-bollywood.html', 'https://aajtak.intoday.in//filmy-gossips.html', 'https://aajtak.intoday.in//film-review.html', 'https://aajtak.intoday.in//celebrity-interview.html', 'https://aajtak.intoday.in//small-screen.html', 'https://aajtak.intoday.in//karyakrams/video/movie-masala.html', 'https://aajtak.intoday.in//viral-video.html', 'https://aajtak.intoday.in//celebrity-birthday-today.html', 'https://aajtak.intoday.in//photos/hollywood.html', 'https://aajtak.intoday.in//style.html', 'https://aajtak.intoday.in//relationship.html', 'https://aajtak.intoday.in//lifestyle-stories.html', 'https://aajtak.intoday.in//diet-and-nutrition-for-women.html', 'https://aajtak.intoday.in//fitness-and-yoga-tips-in-hindi.html', 'https://aajtak.intoday.in//money-tips-for-women-in-hindi.html', 'https://aajtak.intoday.in//tour-travel.html', 'https://aajtak.intoday.in//tech/', 'https://aajtak.intoday.in//mobile.html', 'https://aajtak.intoday.in//auto.html', 'https://aajtak.intoday.in//tech-it-easy.html', 'https://aajtak.intoday.in//social-media.html', 'https://aajtak.intoday.in//tablets-pc-and-laptops.html', 'https://aajtak.intoday.in//videos/tech.html', 'https://aajtak.intoday.in//photos/gadget-gallery.html', 'https://aajtak.intoday.in//sports/', 'https://aajtak.intoday.in//sports/category/cricket.html', 'https://aajtak.intoday.in//scorecard/live-cricket-score/', 'https://aajtak.intoday.in//videos/sports.html', 'https://aajtak.intoday.in//sports/category/sports-news.html', 'https://aajtak.intoday.in//sports/category/sports-personalities-interview.html', 'https://aajtak.intoday.in//sports/category/opinion-on-sports.html', 'https://aajtak.intoday.in//dharam/', 'https://aajtak.intoday.in//dailyrashiphal', 'https://aajtak.intoday.in//religious-places.html', 'https://aajtak.intoday.in//festivals-of-india.html', 'https://aajtak.intoday.in//jigyasa.html', 'https://aajtak.intoday.in//mantra.html', 'https://aajtak.intoday.in//karyakrams/video/dharma.html', 'https://aajtak.intoday.in//states-news.html', 'https://aajtak.intoday.in//madhya-pradesh-news.html', 'https://aajtak.intoday.in//rajasthan-news.html', 'https://aajtak.intoday.in//delhi-news.html', 'https://aajtak.intoday.in//uttar-pradesh-news.html', 'https://aajtak.intoday.in//bihar-news.html', 'https://aajtak.intoday.in//jammu-and-kashmir-news.html', 'https://aajtak.intoday.in//maharashtra-news.html', 'https://aajtak.intoday.in//uttarakhand-news.html', 'https://aajtak.intoday.in//jharkhand-news.html', 'https://aajtak.intoday.in//gujarat-news.html', 'https://aajtak.intoday.in//himachal-news.html', 'https://aajtak.intoday.in//crime/', 'https://aajtak.intoday.in//crime/crime-news-1-781.html', 'https://aajtak.intoday.in//crime/murder-mystery-1-804.html', 'https://aajtak.intoday.in//crime/crimnal-cases-1-780.html', 'https://aajtak.intoday.in//crime/cyber-crime-1-798.html', 'https://aajtak.intoday.in//crime/serial-killer-1-800.html', 'https://aajtak.intoday.in//crime/sex-scandal-1-799.html', 'https://aajtak.intoday.in//crime/bahubali-1-803.html', 'https://aajtak.intoday.in//crime/most-wanted-1-859.html', 'https://aajtak.intoday.in//videos/jurm.html', 'https://aajtak.intoday.in//crime/brave-police-personnel-officers--1-857.html', 'https://aajtak.intoday.in//crime/police-file-se-1-801.html', 'https://aajtak.intoday.in//crime/photos-1.html', 'https://aajtak.intoday.in//podcast.html?utm_source=desktop_h', 'https://aajtak.intoday.in//one-minute.html', 'https://aajtak.intoday.in//din-bhar.html', 'https://aajtak.intoday.in//best-podcasts-in-hindi.html', 'https://aajtak.intoday.in//sahitya.html', 'https://aajtak.intoday.in//sahitya-samiksha.html', 'https://aajtak.intoday.in//sahitya-behes.html', 'https://aajtak.intoday.in//sahitya-interview.html', 'https://aajtak.intoday.in//sahitya-profile.html', 'https://aajtak.intoday.in//videos/sahitya-videos.html', ...

# %%
df=[]
for i in links:
    print(i)
    article = Article(i, language="en")
    try:
      article.download() 
      article.parse() 
      article.nlp() 
    except :
      print("data not found")
    data={}
    data['Title']=article.title
    data['Keywords']=article.keywords
    if "movie" in data['Keywords'] or "bollywood" in data['Keywords'] or "sports" in data['Keywords'] or "star" in data['Keywords'] or "trailers" in data['Keywords']:
      data['data_channel_is_entertainment'] = 1
      data[' data_channel_is_bus'] = 0
      data['data_channel_is_lifestyle'] = 0
    elif "money" in data['Keywords'] or " stocks" in data['Keywords'] or "business" in data['Keywords']  or "rajasthan" in data['Keywords']:
      data['data_channel_is_entertainment'] = 0
      data[' data_channel_is_bus'] = 1
      data['data_channel_is_lifestyle'] = 0
    elif "latest" in data['Keywords'] or "life" in data['Keywords'] or "coronavirus" in data['Keywords'] or "media" in data['Keywords'] or "health" in data['Keywords'] or  "covid-19" in data['Keywords']:
      data['data_channel_is_entertainment'] = 0
      data[' data_channel_is_bus'] = 0
      data['data_channel_is_lifestyle'] = 1
    else:
      data['data_channel_is_entertainment'] = 0
      data[' data_channel_is_bus'] = 0
      data['data_channel_is_lifestyle'] = 0
    df.append(data)
# Out:
# https://aajtak.intoday.in//moviemasala
# https://aajtak.intoday.in//news-on-films.html
# https://aajtak.intoday.in//new-trailer-and-new-songs-of-upcoming-hindi-films-of-bollywood.html
# https://aajtak.intoday.in//filmy-gossips.html
# https://aajtak.intoday.in//film-review.html
# https://aajtak.intoday.in//celebrity-interview.html
# https://aajtak.intoday.in//small-screen.html
# https://aajtak.intoday.in//karyakrams/video/movie-masala.html
# https://aajtak.intoday.in//viral-video.html
# https://aajtak.intoday.in//celebrity-birthday-today.html
# https://aajtak.intoday.in//photos/hollywood.html
# https://aajtak.intoday.in//style.html
# https://aajtak.intoday.in//relationship.html
# https://aajtak.intoday.in//lifestyle-stories.html
# https://aajtak.intoday.in//diet-and-nutrition-for-women.html
# https://aajtak.intoday.in//fitness-and-yoga-tips-in-hindi.html
# https://aajtak.intoday.in//money-tips-for-women-in-hindi.html
# https://aajtak.intoday.in//tour-travel.html
# https://aajtak.intoday.in//tech/
# https://aajtak.intoday.in//mobile.html
# https://aajtak.intoday.in//auto.html
# https://aajtak.intoday.in//tech-it-easy.html
# https://aajtak.intoday.in//social-media.html
# https://aajtak.intoday.in//tablets-pc-and-laptops.html
# https://aajtak.intoday.in//videos/tech.html
# https://aajtak.intoday.in//photos/gadget-gallery.html
# https://aajtak.intoday.in//sports/
# https://aajtak.intoday.in//sports/category/cricket.html
# https://aajtak.intoday.in//scorecard/live-cricket-score/
# https://aajtak.intoday.in//videos/sports.html
# https://aajtak.intoday.in//sports/category/sports-news.html
# https://aajtak.intoday.in//sports/category/sports-personalities-interview.html
# https://aajtak.intoday.in//sports/category/opinion-on-sports.html
# https://aajtak.intoday.in//dharam/
# https://aajtak.intoday.in//dailyrashiphal
# https://aajtak.intoday.in//religious-places.html
# https://aajtak.intoday.in//festivals-of-india.html
# https://aajtak.intoday.in//jigyasa.html
# https://aajtak.intoday.in//mantra.html
# https://aajtak.intoday.in//karyakrams/video/dharma.html
# https://aajtak.intoday.in//states-news.html
# https://aajtak.intoday.in//madhya-pradesh-news.html
# https://aajtak.intoday.in//rajasthan-news.html
# https://aajtak.intoday.in//delhi-news.html
# https://aajtak.intoday.in//uttar-pradesh-news.html
# https://aajtak.intoday.in//bihar-news.html
# https://aajtak.intoday.in//jammu-and-kashmir-news.html
# https://aajtak.intoday.in//maharashtra-news.html
# https://aajtak.intoday.in//uttarakhand-news.html
# https://aajtak.intoday.in//jharkhand-news.html
# https://aajtak.intoday.in//gujarat-news.html
# https://aajtak.intoday.in//himachal-news.html
# https://aajtak.intoday.in//crime/
# https://aajtak.intoday.in//crime/crime-news-1-781.html
# https://aajtak.intoday.in//crime/murder-mystery-1-804.html
# https://aajtak.intoday.in//crime/crimnal-cases-1-780.html
# https://aajtak.intoday.in//crime/cyber-crime-1-798.html
# https://aajtak.intoday.in//crime/serial-killer-1-800.html
# https://aajtak.intoday.in//crime/sex-scandal-1-799.html
# https://aajtak.intoday.in//crime/bahubali-1-803.html
# https://aajtak.intoday.in//crime/most-wanted-1-859.html
# https://aajtak.intoday.in//videos/jurm.html
# https://aajtak.intoday.in//crime/brave-police-personnel-officers--1-857.html
# https://aajtak.intoday.in//crime/police-file-se-1-801.html
# https://aajtak.intoday.in//crime/photos-1.html
# https://aajtak.intoday.in//podcast.html?utm_source=desktop_h
# https://aajtak.intoday.in//one-minute.html
# https://aajtak.intoday.in//din-bhar.html
# https://aajtak.intoday.in//best-podcasts-in-hindi.html
# https://aajtak.intoday.in//sahitya.html
# https://aajtak.intoday.in//sahitya-samiksha.html
# https://aajtak.intoday.in//sahitya-behes.html
# https://aajtak.intoday.in//sahitya-interview.html
# https://aajtak.intoday.in//sahitya-profile.html
# https://aajtak.intoday.in//videos/sahitya-videos.html
# https://aajtak.intoday.in//photos/sahitya.html
# https://aajtak.intoday.in//sahitya/2018/
# data not found
# https://aajtak.intoday.in//sahitya/2017/
# https://aajtak.intoday.in//sahitya/2016/
# data not found
# https://aajtak.intoday.in//women/
# https://aajtak.intoday.in//successful-women.html
# https://aajtak.intoday.in//pregnancy.html
# https://aajtak.intoday.in//parenting-tips-in-hindi.html
# https://aajtak.intoday.in//beauty-tips.html
# https://aajtak.intoday.in//fashion.html
# https://aajtak.intoday.in//makeup-tips.html
# https://aajtak.intoday.in//housekeeping-tips-in-hindi.html
# https://aajtak.intoday.in//education/
# https://aajtak.intoday.in//education/category/private-govt-psu-jobs.html
# https://aajtak.intoday.in//education/category/education-career-job-news.html
# https://aajtak.intoday.in//education/category/general-knowledge-in-hindi.html
# https://aajtak.intoday.in//education/category/current-affairs-in-hindi.html
# https://aajtak.intoday.in//education/category/sucess-stories.html
# https://aajtak.intoday.in//karyakrams.html
# https://aajtak.intoday.in//karyakrams/video/das-tak.html
# https://aajtak.intoday.in//karyakrams/video/special-report.html
# https://aajtak.intoday.in//karyakrams/video/dharma.html
# https://aajtak.intoday.in//karyakrams/video/vardaat.html
# https://aajtak.intoday.in//karyakrams/video/dangal.html
# https://aajtak.intoday.in//karyakrams/video/halla-bol.html
# https://aajtak.intoday.in//karyakrams/video/mumbai-metro.html
# https://aajtak.intoday.in//karyakrams/video/vishesh.html
# https://aajtak.intoday.in//karyakrams/video/saas-bahu-aur-betiya.html
# https://aajtak.intoday.in//karyakrams/video/so-sorry.html
# https://aajtak.intoday.in//karyakrams/video/subah-subah.html
# https://aajtak.intoday.in//karyakrams/video/ek-aur-ek-gyarah.html
# https://aajtak.intoday.in//karyakrams/video/desh-tak.html
# https://aajtak.intoday.in//sosorry
# https://aajtak.intoday.in//karyakrams/video/best-of-so-sorry.html
# https://aajtak.intoday.in//business.html
# https://aajtak.intoday.in//calender.php
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//sosorry/
# https://aajtak.intoday.in//
# https://aajtak.intoday.in//news.html
# https://aajtak.intoday.in//national.html
# https://aajtak.intoday.in//world-news.html
# https://aajtak.intoday.in//sports
# https://aajtak.intoday.in//business.html
# https://aajtak.intoday.in//states-news.html
# https://aajtak.intoday.in//photos.html
# https://aajtak.intoday.in//photos/entertainment.html
# https://aajtak.intoday.in//photos/sports.html
# https://aajtak.intoday.in//photos/business.html
# https://aajtak.intoday.in//photos/world.html
# https://aajtak.intoday.in//photos/lifestyle.html
# https://aajtak.intoday.in//photos/relationship.html
# https://aajtak.intoday.in//photos/dharma.html
# https://aajtak.intoday.in//photos/national.html
# https://aajtak.intoday.in//videos.html
# https://aajtak.intoday.in//videos/national.html
# https://aajtak.intoday.in//videos/entertainment.html
# https://aajtak.intoday.in//videos/jurm.html
# https://aajtak.intoday.in//karyakrams.html
# https://aajtak.intoday.in//sosorry
# https://aajtak.intoday.in//videos/sports.html
# https://aajtak.intoday.in//videos/tech.html
# https://aajtak.intoday.in//videos/world.html
# https://aajtak.intoday.in//videos/main-bhi-anchor.html
# https://aajtak.intoday.in//coronavirus-covid-19-outbreak
# https://aajtak.intoday.in//moviemasala/
# https://aajtak.intoday.in//fact-check.html
# https://aajtak.intoday.in//podcast.html?utm_source=desktop_t
# https://aajtak.intoday.in//livetv.html
# https://aajtak.intoday.in//livetv.html
# https://aajtak.intoday.in//livetv.html?livetv=audio
# https://aajtak.intoday.in//dilliaajtak/livetv.php
# https://aajtak.intoday.in//teztv.php
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//news/liveblog/coronavirus-india-covid-19-positive-cases-death-toll-28-april-delhi-maharashtra-lockdown-live-news-updates-896.html
# https://aajtak.intoday.in//story/comedian-kapil-sharma-show-live-with-prime-minister-narendra-modi-answer-of-comdian-on-twitter-tmov-1-1185448.html
# https://aajtak.intoday.in//story/comedian-kapil-sharma-show-live-with-prime-minister-narendra-modi-answer-of-comdian-on-twitter-tmov-1-1185448.html
# https://aajtak.intoday.in//story/coronavirus-lockdown-congress-party-leader-manish-tewari-modi-govt-1-1185430.html
# https://aajtak.intoday.in//story/coronavirus-lockdown-congress-party-leader-manish-tewari-modi-govt-1-1185430.html
# https://aajtak.intoday.in//story/return-antibody-testing-kits-from-guangzhou-wondfo-biotech-and-zhuhai-livzon-diagnostics-icmr-1-1185449.html
# https://aajtak.intoday.in//story/return-antibody-testing-kits-from-guangzhou-wondfo-biotech-and-zhuhai-livzon-diagnostics-icmr-1-1185449.html
# https://aajtak.intoday.in//crime/story/corona-covid-19-world-greatest-tragedy-cemetery-corpses-burial-scarcity-trouble-crime-1-1185400.html
# https://aajtak.intoday.in//crime/story/corona-covid-19-world-greatest-tragedy-cemetery-corpses-burial-scarcity-trouble-crime-1-1185400.html
# https://aajtak.intoday.in//education/story/cbse-board-exams-hrd-ministry-meeting-manish-sisodia-not-possible-to-conduct-remaining-exam-tedu-1-1185438.html
# https://aajtak.intoday.in//education/story/cbse-board-exams-hrd-ministry-meeting-manish-sisodia-not-possible-to-conduct-remaining-exam-tedu-1-1185438.html
# https://aajtak.intoday.in//gallery/auraiya-sajanpur-village-achalda-children-playing-cricket-dug-up-land-got-30-silver-coins-tstn-1-49527.html
# https://aajtak.intoday.in//story/india-today-e-conclave-corona-series-pulitzer-prize-winner-thomas-friedman-on-humanitys-fight-against-covid-19-1-1185442.html
# https://aajtak.intoday.in//gallery/when-will-asteroid-1998-or2-come-close-to-earth-at-what-time-flyby-pass-ulkapind-nasa-tstr-1-49521.html
# data not found
# https://aajtak.intoday.in//story/bollywood-actor-sharman-joshi-birthday-special-why-actor-replaced-by-rohit-shetty-tmov-1-1185405.html
# data not found
# https://aajtak.intoday.in//story/suresh-tiwary-up-bjp-mla-bjp-president-jp-nadda-swtantradev-singh-1-1185429.html
# https://aajtak.intoday.in//karyakram/video/dangal-debate-islamic-scholar-shoaib-jamai-bats-for-jammatis-plasma-donation-rohit-sardana-1-1185447.html
# https://aajtak.intoday.in//story/first-covid-19-death-in-central-para-military-forces-sub-insp-of-crpf-safdarjung-hospital-1-1185434.html
# https://aajtak.intoday.in//story/irrfan-khan-suffering-from-colon-infection-health-update-admit-in-kokilaben-hospital-tmov-1-1185433.html
# https://aajtak.intoday.in//story/aajtak-digital-in-support-of-coronavirus-awareness-campaign-will-give-newsletter-on-covid19-1-1175040.html
# https://aajtak.intoday.in//education/story/masters-union-school-of-business-musb-is-going-to-be-established-in-gurugram-tedu-1-1184130.html
# https://aajtak.intoday.in//video/coronavirus-lockdown-delhi-haryana-border-sealed-anil-vij-satyendra-jain-1-1185373.html
# data not found
# https://aajtak.intoday.in//video/mumbai-mayor-dons-nurse-in-solidarity-with-health-workers-1-1185369.html
# data not found
# https://aajtak.intoday.in//video/delhi-govt-relaxes-lockdown-for-few-services-coronavirus-covid-19-1-1185357.html
# data not found
# https://aajtak.intoday.in//video/actor-irrfan-khan-admitted-to-hospital-after-his-health-deteriorates-bollywood-news-in-hindi-1-1185352.html
# data not found
# https://aajtak.intoday.in//khabare-ab-tak.html
# https://aajtak.intoday.in//khabare-ab-tak.html
# https://aajtak.intoday.in//story/kareena-kapoor-behind-the-scene-ishq-what-women-want-chat-show-tmov-1-1185390.html
# data not found
# https://aajtak.intoday.in//story/kerala-high-court-salary-stay-corona-virus-covid-19-1-1185437.html
# https://aajtak.intoday.in//education/story/coronavirus-cbse-10th-and-12th-board-examinations-secy-anurag-tripathi-says-tedu-1-1185426.html
# https://aajtak.intoday.in//story/rjd-supremo-lalu-yadav-rims-corona-virus-positive-ranchi-covid-19-1-1185388.html
# https://aajtak.intoday.in//gallery/coronavirus-china-schools-students-in-classroom-know-how-they-reach-tedu-1-49523.html
# data not found
# https://aajtak.intoday.in//story/corona-lockdown-industry-many-sectors-ruined-job-loss-hope-too-long-for-them-tutd-1-1185247.html
# https://aajtak.intoday.in//story/jammu-kashmir-encounter-started-between-militants-and-joint-team-of-forces-melhora-village-shopian-1-1185384.html
# https://aajtak.intoday.in//videos.html
# https://aajtak.intoday.in//videos.html
# https://aajtak.intoday.in//karyakram/video/desh-tak-coronavirus-updates-total-cases-nears-30000-mark-maharashtra-worst-hit-gujarat-no-better-1-1185460.html
# https://aajtak.intoday.in//karyakram/video/desh-tak-coronavirus-updates-total-cases-nears-30000-mark-maharashtra-worst-hit-gujarat-no-better-1-1185460.html
# https://aajtak.intoday.in//video/india-could-hit-on-api-as-chinese-threats-to-ban-medical-phanrma-supplies-amid-coronavirus-outbreak-1-1185452.html
# https://aajtak.intoday.in//video/india-could-hit-on-api-as-chinese-threats-to-ban-medical-phanrma-supplies-amid-coronavirus-outbreak-1-1185452.html
# https://aajtak.intoday.in//karyakram/video/dangal-debate-islamic-scholar-shoaib-jamai-bats-for-jammatis-plasma-donation-rohit-sardana-1-1185447.html
# https://aajtak.intoday.in//karyakram/video/dangal-debate-islamic-scholar-shoaib-jamai-bats-for-jammatis-plasma-donation-rohit-sardana-1-1185447.html
# https://aajtak.intoday.in//karyakram/video/halla-bol-coronavirus-lockdown-has-positive-impact-then-why-political-sulgfest-1-1185440.html
# https://aajtak.intoday.in//karyakram/video/halla-bol-coronavirus-lockdown-has-positive-impact-then-why-political-sulgfest-1-1185440.html
# https://aajtak.intoday.in//moviemasala
# https://aajtak.intoday.in//moviemasala
# https://aajtak.intoday.in//story/comedian-kapil-sharma-show-live-with-prime-minister-narendra-modi-answer-of-comdian-on-twitter-tmov-1-1185448.html
# https://aajtak.intoday.in//story/comedian-kapil-sharma-show-live-with-prime-minister-narendra-modi-answer-of-comdian-on-twitter-tmov-1-1185448.html
# https://aajtak.intoday.in//story/shashi-kapoor-bollywood-actor-unknown-facts-when-said-this-director-will-kill-me-manmohan-desai-tmov-1-1185446.html
# https://aajtak.intoday.in//story/shashi-kapoor-bollywood-actor-unknown-facts-when-said-this-director-will-kill-me-manmohan-desai-tmov-1-1185446.html
# https://aajtak.intoday.in//story/irrfan-khan-suffering-from-colon-infection-health-update-admit-in-kokilaben-hospital-tmov-1-1185433.html
# https://aajtak.intoday.in//story/irrfan-khan-suffering-from-colon-infection-health-update-admit-in-kokilaben-hospital-tmov-1-1185433.html
# https://aajtak.intoday.in//story/film-wrap-latest-bollywood-entertainment-tv-news-of-tuesday-tmov-1-1185425.html
# https://aajtak.intoday.in//story/film-wrap-latest-bollywood-entertainment-tv-news-of-tuesday-tmov-1-1185425.html
# https://aajtak.intoday.in//story/bollywood-actor-sharman-joshi-birthday-special-why-actor-replaced-by-rohit-shetty-tmov-1-1185405.html
# data not found
# https://aajtak.intoday.in//story/bollywood-actor-sharman-joshi-birthday-special-why-actor-replaced-by-rohit-shetty-tmov-1-1185405.html
# data not found
# https://aajtak.intoday.in//story/anushka-sharma-opens-introduction-scene-of-dil-dhadakne-do-shares-video-tmov-1-1185394.html
# data not found
# https://aajtak.intoday.in//story/anushka-sharma-opens-introduction-scene-of-dil-dhadakne-do-shares-video-tmov-1-1185394.html
# data not found
# https://aajtak.intoday.in//story/kareena-kapoor-behind-the-scene-ishq-what-women-want-chat-show-tmov-1-1185390.html
# data not found
# https://aajtak.intoday.in//story/kareena-kapoor-behind-the-scene-ishq-what-women-want-chat-show-tmov-1-1185390.html
# data not found
# https://aajtak.intoday.in//story/kareena-kapoor-khan-abhishek-bachchan-first-movie-asked-him-closet-friend-ever-tmov-1-1185347.html
# data not found
# https://aajtak.intoday.in//story/kareena-kapoor-khan-abhishek-bachchan-first-movie-asked-him-closet-friend-ever-tmov-1-1185347.html
# data not found
# https://aajtak.intoday.in//photos.html
# https://aajtak.intoday.in//photos.html
# https://aajtak.intoday.in//gallery/sunil-lahri-revealed-bollywood-actors-as-ramayan-characters-best-probability-tmov-1-49510.html
# https://aajtak.intoday.in//gallery/sunil-lahri-revealed-bollywood-actors-as-ramayan-characters-best-probability-tmov-1-49510.html
# https://aajtak.intoday.in//gallery/mahabharat-actor-nitish-bharadwaj-did-not-wanted-to-play-krishna-rejected-nakul-sahdev-role-casting-unknown-facts-tmov-1-49505.html
# https://aajtak.intoday.in//gallery/mahabharat-actor-nitish-bharadwaj-did-not-wanted-to-play-krishna-rejected-nakul-sahdev-role-casting-unknown-facts-tmov-1-49505.html
# https://aajtak.intoday.in//gallery/bigg-boss-2-winner-ashutosh-kaushik-marriage-amid-corona-lockdown-roadies-winner-controversy-tmov-1-49506.html
# https://aajtak.intoday.in//gallery/bigg-boss-2-winner-ashutosh-kaushik-marriage-amid-corona-lockdown-roadies-winner-controversy-tmov-1-49506.html
# https://aajtak.intoday.in//gallery/ramanand-sagar-ramayan-lakshman-son-krish-pathak-full-profile-career-bollywood-entry-tmov-1-49501.html
# https://aajtak.intoday.in//gallery/ramanand-sagar-ramayan-lakshman-son-krish-pathak-full-profile-career-bollywood-entry-tmov-1-49501.html
# https://aajtak.intoday.in//gallery/paras-slams-shehnaaz-calls-her-irritating-arrogant-has-not-talked-her-after-mujhse-shaadi-karoge-ends-tmov-1-49500.html
# https://aajtak.intoday.in//gallery/paras-slams-shehnaaz-calls-her-irritating-arrogant-has-not-talked-her-after-mujhse-shaadi-karoge-ends-tmov-1-49500.html
# https://aajtak.intoday.in//gallery/mahabharat-draupadi-aka-pooja-sharma-on-cheer-haran-scene-shoot-look-test-unknown-facts-tmov-1-49497.html
# https://aajtak.intoday.in//gallery/mahabharat-draupadi-aka-pooja-sharma-on-cheer-haran-scene-shoot-look-test-unknown-facts-tmov-1-49497.html
# https://aajtak.intoday.in//gallery/mahabharat-bhim-praveen-kumar-sobti-in-politics-arvind-kejriwal-tmov-1-49481.html
# https://aajtak.intoday.in//gallery/mahabharat-bhim-praveen-kumar-sobti-in-politics-arvind-kejriwal-tmov-1-49481.html
# https://aajtak.intoday.in//sports/
# https://aajtak.intoday.in//sports/
# https://aajtak.intoday.in//sports/story/aakash-chopra-ms-dhoni-comeback-ipl-2020-dependent-indian-cricket-team-tspo-1-1185403.html
# https://aajtak.intoday.in//sports/story/aakash-chopra-ms-dhoni-comeback-ipl-2020-dependent-indian-cricket-team-tspo-1-1185403.html
# https://aajtak.intoday.in//sports/story/chris-gayle-lashes-out-ramnaresh-sarwan-you-are-a-snake-worse-than-coronavirus-tspo-1-1185389.html
# https://aajtak.intoday.in//sports/story/chris-gayle-lashes-out-ramnaresh-sarwan-you-are-a-snake-worse-than-coronavirus-tspo-1-1185389.html
# https://aajtak.intoday.in//sports/story/harbhajan-singh-haircut-confuse-coronavirus-photo-shared-on-instagram-bhajji-tspo-1-1185341.html
# data not found
# https://aajtak.intoday.in//sports/story/harbhajan-singh-haircut-confuse-coronavirus-photo-shared-on-instagram-bhajji-tspo-1-1185341.html
# data not found
# https://aajtak.intoday.in//sports/story/australia-batsman-lynn-says-t20-wc-shouldnt-go-ahead-calls-it-logistical-nightmare-tspo-1-1185325.html
# data not found
# https://aajtak.intoday.in//sports/story/australia-batsman-lynn-says-t20-wc-shouldnt-go-ahead-calls-it-logistical-nightmare-tspo-1-1185325.html
# data not found
# https://aajtak.intoday.in//business.html
# https://aajtak.intoday.in//business.html
# https://aajtak.intoday.in//story/sbi-bank-branch-ghaziabad-vijay-nagar-coronavirus-covid-19-aarogya-setu-app-alert-tstc-1-1185427.html
# https://aajtak.intoday.in//story/turkey-to-impose-three-day-lockdown-in-31-provinces-due-to-kovid-19-tuta-1-1185379.html
# https://aajtak.intoday.in//story/bank-loan-crores-write-off-50-big-defaulters-including-mehul-choksi-congress-attack-bjp-government-tutd-1-1185363.html
# https://aajtak.intoday.in//story/uidai-aadhaar-card-updation-can-now-be-done-at-common-service-centres-ravi-shankar-prasad-tutk-1-1185359.html
# data not found
# https://aajtak.intoday.in//story/axis-bank-to-take-29-percent-stake-in-max-life-insurance-big-bet-tutd-1-1185338.html
# https://aajtak.intoday.in//story/covid-19-lockdowns-lic-achieved-above-25-per-cent-growth-new-business-premium-2019-20-private-players-tutk-1-1185304.html
# https://aajtak.intoday.in//story/lockdown-reduction-in-unemployment-rate-job-loss-more-than-7-crore-people-left-work-force-tutd-1-1185281.html
# https://aajtak.intoday.in//crime/
# https://aajtak.intoday.in//crime/
# https://aajtak.intoday.in//crime/story/corona-north-korea-supreme-leader-kim-jong-un-missing-critical-condition-heir-sister-rumor-crime-1-1185421.html
# https://aajtak.intoday.in//crime/story/corona-north-korea-supreme-leader-kim-jong-un-missing-critical-condition-heir-sister-rumor-crime-1-1185421.html
# https://aajtak.intoday.in//crime/story/corona-covid-19-world-greatest-tragedy-cemetery-corpses-burial-scarcity-trouble-crime-1-1185400.html
# https://aajtak.intoday.in//crime/story/corona-covid-19-world-greatest-tragedy-cemetery-corpses-burial-scarcity-trouble-crime-1-1185400.html
# https://aajtak.intoday.in//crime/story/madhya-pradesh-jabalpur-lockdown-two-girls-smoke-cigarette-police-video-viral-tstc-1-1185370.html
# https://aajtak.intoday.in//crime/story/madhya-pradesh-jabalpur-lockdown-two-girls-smoke-cigarette-police-video-viral-tstc-1-1185370.html
# https://aajtak.intoday.in//crime/story/lock-down-a-dead-body-of-railway-staff-found-in-vacant-flat-case-registered-against-unidentified-people-1-1185350.html
# https://aajtak.intoday.in//crime/story/lock-down-a-dead-body-of-railway-staff-found-in-vacant-flat-case-registered-against-unidentified-people-1-1185350.html
# https://aajtak.intoday.in//crime/story/corona-lockdown-north-korea-supreme-leader-kim-jong-un-missing-condition-critical-news-crime-1-1185349.html
# https://aajtak.intoday.in//crime/story/corona-lockdown-north-korea-supreme-leader-kim-jong-un-missing-condition-critical-news-crime-1-1185349.html
# https://aajtak.intoday.in//story/coronavirus-gujarat-surat-factory-labour-protest-police-stonepelting-1-1185303.html
# https://aajtak.intoday.in//story/coronavirus-gujarat-surat-factory-labour-protest-police-stonepelting-1-1185303.html
# https://aajtak.intoday.in//states-news.html
# https://aajtak.intoday.in//states-news.html
# https://aajtak.intoday.in//story/dolphin-spotted-ganga-river-meerut-video-viral-tstc-1-1185439.html
# data not found
# https://aajtak.intoday.in//story/suresh-tiwary-up-bjp-mla-bjp-president-jp-nadda-swtantradev-singh-1-1185429.html
# https://aajtak.intoday.in//story/sbi-bank-branch-ghaziabad-vijay-nagar-coronavirus-covid-19-aarogya-setu-app-alert-tstc-1-1185427.html
# https://aajtak.intoday.in//story/lockdown-corona-virus-cm-yogi-praised-team-11-to-show-his-dedication-to-fight-against-covid-19-1-1185407.html
# https://aajtak.intoday.in//story/village-sealed-in-auraiya-district-of-up-after-a-policemen-found-positive-1-1185392.html
# https://aajtak.intoday.in//story/corona-virus-powerloom-workers-started-walking-bhiwandi-to-prayagraj-1400-kilometers-lockdown-1-1185372.html
# https://aajtak.intoday.in//story/lucknow-police-sub-inspector-nida-arshi-come-police-station-with-child-corona-virus-1-1185368.html
# data not found
# https://aajtak.intoday.in//tech
# https://aajtak.intoday.in//tech
# https://aajtak.intoday.in//story/tech-wrap-of-the-day-28-april-2020-ttec-1-1185422.html
# https://aajtak.intoday.in//story/tech-wrap-of-the-day-28-april-2020-ttec-1-1185422.html
# https://aajtak.intoday.in//story/redmi-note-9-series-to-get-a-new-phone-on-april-30-check-more-details-ttec-1-1185412.html
# https://aajtak.intoday.in//story/redmi-note-9-series-to-get-a-new-phone-on-april-30-check-more-details-ttec-1-1185412.html
# https://aajtak.intoday.in//story/airtel-and-nokia-multi-year-deal-to-boost-network-capacity-and-user-experience-ttec-1-1185382.html
# https://aajtak.intoday.in//story/airtel-and-nokia-multi-year-deal-to-boost-network-capacity-and-user-experience-ttec-1-1185382.html
# https://aajtak.intoday.in//story/xiaomi-mi-bluetooth-earphones-and-mi-watch-color-keith-haring-launched-in-china-ttec-1-1185353.html
# https://aajtak.intoday.in//story/xiaomi-mi-bluetooth-earphones-and-mi-watch-color-keith-haring-launched-in-china-ttec-1-1185353.html
# https://aajtak.intoday.in//story/vivo-beats-samsung-in-indian-smartphone-sales-for-the-first-time-q1-2020-canalys-data-ttec-1-1185312.html
# https://aajtak.intoday.in//story/vivo-beats-samsung-in-indian-smartphone-sales-for-the-first-time-q1-2020-canalys-data-ttec-1-1185312.html
# https://aajtak.intoday.in//story/whatsapp-for-iphone-gets-updated-group-video-calling-support-ttec-1-1185260.html
# https://aajtak.intoday.in//story/whatsapp-for-iphone-gets-updated-group-video-calling-support-ttec-1-1185260.html
# https://aajtak.intoday.in//karyakrams.html
# https://aajtak.intoday.in//karyakrams.html
# https://aajtak.intoday.in//karyakram/video/so-sorry-watch-corombo-vs-mr-india-coronavirus-covid-19-pm-narendra-modi-1-1184668.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-watch-corombo-vs-mr-india-coronavirus-covid-19-pm-narendra-modi-1-1184668.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-lockdown-2-0-pm-narendra-modi-as-smart-boy-coronavirus-as-lion-hindi-1-1182695.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-lockdown-2-0-pm-narendra-modi-as-smart-boy-coronavirus-as-lion-hindi-1-1182695.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-gabbar-corona-lockdown-extension-covid-19-1-1181502.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-gabbar-corona-lockdown-extension-covid-19-1-1181502.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-lockdown-will-be-extended-coronavirus-1-1179486.html
# data not found
# https://aajtak.intoday.in//karyakram/video/so-sorry-lockdown-will-be-extended-coronavirus-1-1179486.html
# data not found
# https://aajtak.intoday.in//style.html
# https://aajtak.intoday.in//style.html
# https://aajtak.intoday.in//story/coronavirus-couple-goals-during-lockdown-help-your-relationship-tlif-1-1185351.html
# https://aajtak.intoday.in//story/coronavirus-couple-goals-during-lockdown-help-your-relationship-tlif-1-1185351.html
# https://aajtak.intoday.in//story/e-agenga-jaan-hai-to-jahan-hai-lockdown-cannot-relief-from-corona-virus-said-dr-rajesh-parikh-tlif-1-1184424.html
# https://aajtak.intoday.in//story/e-agenga-jaan-hai-to-jahan-hai-lockdown-cannot-relief-from-corona-virus-said-dr-rajesh-parikh-tlif-1-1184424.html
# https://aajtak.intoday.in//story/e-agenda-aaj-tak-2020-corona-virus-chini-virus-desi-ilaaj-neurotherapy-tlif-1-1184377.html
# https://aajtak.intoday.in//story/e-agenda-aaj-tak-2020-corona-virus-chini-virus-desi-ilaaj-neurotherapy-tlif-1-1184377.html
# https://aajtak.intoday.in//story/eagenda-aaj-tak-2020-chini-virus-desi-ilaaj-immunity-meena-tlif-1-1184350.html
# https://aajtak.intoday.in//story/eagenda-aaj-tak-2020-chini-virus-desi-ilaaj-immunity-meena-tlif-1-1184350.html
# https://aajtak.intoday.in//story/e-agenda-baba-ramdev-suggest-5-pranayam-ram-baan-se-bhagega-corona-tlif-1-1184340.html
# https://aajtak.intoday.in//story/e-agenda-baba-ramdev-suggest-5-pranayam-ram-baan-se-bhagega-corona-tlif-1-1184340.html
# https://aajtak.intoday.in//story/e-agenda-aaj-tak-jaan-hai-to-jahan-hai-when-corona-virus-vaccine-successfully-developed-tlif-1-1184329.html
# https://aajtak.intoday.in//story/e-agenda-aaj-tak-jaan-hai-to-jahan-hai-when-corona-virus-vaccine-successfully-developed-tlif-1-1184329.html
# https://aajtak.intoday.in//khabare-jara-hatke.html
# https://aajtak.intoday.in//khabare-jara-hatke.html
# https://aajtak.intoday.in//story/snake-cobra-mangoose-fight-video-viral-social-media-1-1172289.html
# data not found
# https://aajtak.intoday.in//story/snake-cobra-mangoose-fight-video-viral-social-media-1-1172289.html
# data not found
# https://aajtak.intoday.in//story/people-get-confused-over-dog-as-lion-photo-viral-tsta-1-1170738.html
# https://aajtak.intoday.in//story/people-get-confused-over-dog-as-lion-photo-viral-tsta-1-1170738.html
# https://aajtak.intoday.in//story/noida-police-alert-all-on-holi-says-not-to-drink-and-drive-1-1169790.html
# https://aajtak.intoday.in//story/noida-police-alert-all-on-holi-says-not-to-drink-and-drive-1-1169790.html
# https://aajtak.intoday.in//story/chinese-takeaway-delivered-meal-contained-human-tooth-tsta-1-1168161.html
# https://aajtak.intoday.in//story/chinese-takeaway-delivered-meal-contained-human-tooth-tsta-1-1168161.html
# https://aajtak.intoday.in//indiatoday-hindi
# https://aajtak.intoday.in//indiatoday-hindi
# https://aajtak.intoday.in//story/monsoon-environment-agriculture-paddy-wheat-sugercane-1-1185030.html
# https://aajtak.intoday.in//story/monsoon-environment-agriculture-paddy-wheat-sugercane-1-1185030.html
# https://aajtak.intoday.in//story/cracking-the-covid-cure-code-1-1184509.html
# https://aajtak.intoday.in//story/cracking-the-covid-cure-code-1-1184509.html
# https://aajtak.intoday.in//story/a-harrowing-task-no-more-1-1184508.html
# https://aajtak.intoday.in//story/a-harrowing-task-no-more-1-1184508.html
# https://aajtak.intoday.in//story/coronavirus-pandemic-posturing-in-west-bengal-1-1184505.html
# https://aajtak.intoday.in//story/coronavirus-pandemic-posturing-in-west-bengal-1-1184505.html
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//photos/trending-clicks.html
# https://aajtak.intoday.in//photos/trending-clicks.html
# https://aajtak.intoday.in//gallery/auraiya-sajanpur-village-achalda-children-playing-cricket-dug-up-land-got-30-silver-coins-tstn-1-49527.html
# https://aajtak.intoday.in//gallery/auraiya-sajanpur-village-achalda-children-playing-cricket-dug-up-land-got-30-silver-coins-tstn-1-49527.html
# https://aajtak.intoday.in//gallery/iit-bombay-student-and-his-friends-in-jammu-and-kashmir-develop-low-cost-mechanical-ventilator-corona-virus-tstk-1-49525.html
# https://aajtak.intoday.in//gallery/iit-bombay-student-and-his-friends-in-jammu-and-kashmir-develop-low-cost-mechanical-ventilator-corona-virus-tstk-1-49525.html
# https://aajtak.intoday.in//gallery/when-will-asteroid-1998-or2-come-close-to-earth-at-what-time-flyby-pass-ulkapind-nasa-tstr-1-49521.html
# data not found
# https://aajtak.intoday.in//gallery/when-will-asteroid-1998-or2-come-close-to-earth-at-what-time-flyby-pass-ulkapind-nasa-tstr-1-49521.html
# data not found
# https://aajtak.intoday.in//gallery/728-iranians-killed-drinking-methanol-false-belief-it-protects-from-coronavirus-tstk-1-49518.html
# https://aajtak.intoday.in//gallery/728-iranians-killed-drinking-methanol-false-belief-it-protects-from-coronavirus-tstk-1-49518.html
# https://aajtak.intoday.in//gallery/coronavirus-america-top-emergency-room-doctor-died-by-suicide-tsta-1-49516.html
# https://aajtak.intoday.in//gallery/coronavirus-america-top-emergency-room-doctor-died-by-suicide-tsta-1-49516.html
# https://aajtak.intoday.in/javascript:;
# data not found
# https://aajtak.intoday.in//video/agenda-aajtak-2019-ayushmann-khurrana-talks-on-bollywood-cab-jamia-in-andhadhun-superhits-session-1-1146751.html
# https://aajtak.intoday.in//video/agenda-aajtak-2019-ayushmann-khurrana-talks-on-bollywood-cab-jamia-in-andhadhun-superhits-session-1-1146751.html
# https://aajtak.intoday.in//video/agenda-aajtak-2019-akshay-kumar-upcoming-film-good-news-gives-success-formula-of-giving-hit-films-video-1-1146911.html
# https://aajtak.intoday.in//video/agenda-aajtak-2019-akshay-kumar-upcoming-film-good-news-gives-success-formula-of-giving-hit-films-video-1-1146911.html
# https://aajtak.intoday.in//video/comedian-raju-srivastav-tells-winter-season-advantages-on-agenda-aajtak-2018-1-1047405.html
# data not found
# https://aajtak.intoday.in//video/comedian-raju-srivastav-tells-winter-season-advantages-on-agenda-aajtak-2018-1-1047405.html
# data not found
# https://aajtak.intoday.in//video/sunil-grover-teaches-gidda-dance-in-the-session-of-agenda-aajtak-tmov-1-1047695.html
# data not found
# https://aajtak.intoday.in//video/sunil-grover-teaches-gidda-dance-in-the-session-of-agenda-aajtak-tmov-1-1047695.html
# data not found
# https://aajtak.intoday.in//video/bollywood-singer-armaan-malik-tells-about-her-singing-career-in-agenda-aajtak-2018-1-1047460.html
# data not found
# https://aajtak.intoday.in//video/bollywood-singer-armaan-malik-tells-about-her-singing-career-in-agenda-aajtak-2018-1-1047460.html
# data not found
# https://aajtak.intoday.in//dharam
# https://aajtak.intoday.in//dharam
# https://aajtak.intoday.in//story/chanakya-niti-in-hindi-life-is-more-important-than-money-and-wife-says-kautilya-lbs-1-1185285.html
# https://aajtak.intoday.in//story/chanakya-niti-in-hindi-life-is-more-important-than-money-and-wife-says-kautilya-lbs-1-1185285.html
# https://aajtak.intoday.in//story/chanakya-niti-in-hindi-way-save-your-life-and-get-success-chanakya-quotes-hapiness-lbs-1-1185209.html
# https://aajtak.intoday.in//story/chanakya-niti-in-hindi-way-save-your-life-and-get-success-chanakya-quotes-hapiness-lbs-1-1185209.html
# https://aajtak.intoday.in//story/horoscope-today-28-april-2020-aaj-ka-rashifal-sunday-ka-rashifal-tlifd-1-1185188.html
# https://aajtak.intoday.in//story/horoscope-today-28-april-2020-aaj-ka-rashifal-sunday-ka-rashifal-tlifd-1-1185188.html
# https://aajtak.intoday.in//story/tarot-horoscope-28-april-2020-tarot-rashifal-in-hindi-tarot-card-zodiac-sign-tuesday-astrology-prediction-lbs-1-1185117.html
# https://aajtak.intoday.in//story/tarot-horoscope-28-april-2020-tarot-rashifal-in-hindi-tarot-card-zodiac-sign-tuesday-astrology-prediction-lbs-1-1185117.html
# https://aajtak.intoday.in//dailyrashiphal
# https://aajtak.intoday.in//rashiphal/video/aries/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/taurush/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/gemini/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/cancer/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/leo/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/virgo/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/libra/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/scorpio/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/sagittarius/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/capricorn/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/aquarius/aapketaren-daily
# https://aajtak.intoday.in//rashiphal/video/pisces/aapketaren-daily
# https://aajtak.intoday.in//sahitya.html
# https://aajtak.intoday.in//sahitya.html
# https://aajtak.intoday.in//story/ramdhari-singh-dinkar-death-anniversary-special-dinkar-life-works-and-poems-1-1184007.html
# https://aajtak.intoday.in//story/l-surbramaniam-abhay-k-and-kavita-krishnamurti-come-together-with-earth-anthem-on-golden-jubilee-of-earth-day-1-1183267.html
# https://aajtak.intoday.in//story/arundhati-roy-book-ek-tha-doctor-ek-tha-sant-claims-savarkar-suported-mahad-satyagraha-1-1180734.html
# https://aajtak.intoday.in//story/s-r-harnot-two-poems-on-natures-healing-during-corona-lockdown-1-1180405.html
# https://aajtak.intoday.in//education/
# https://aajtak.intoday.in//education/
# https://aajtak.intoday.in//education/story/cbse-board-exams-hrd-ministry-meeting-manish-sisodia-not-possible-to-conduct-remaining-exam-tedu-1-1185438.html
# https://aajtak.intoday.in//education/story/cbse-board-exams-hrd-ministry-meeting-manish-sisodia-not-possible-to-conduct-remaining-exam-tedu-1-1185438.html
# https://aajtak.intoday.in//education/story/coronavirus-cbse-10th-and-12th-board-examinations-secy-anurag-tripathi-says-tedu-1-1185426.html
# https://aajtak.intoday.in//education/story/coronavirus-cbse-10th-and-12th-board-examinations-secy-anurag-tripathi-says-tedu-1-1185426.html
# https://aajtak.intoday.in//education/story/coronavirus-icai-free-courses-in-lockdown-see-link-here-tedu-1-1185371.html
# https://aajtak.intoday.in//education/story/coronavirus-icai-free-courses-in-lockdown-see-link-here-tedu-1-1185371.html
# https://aajtak.intoday.in//education/story/hsl-recruitment-2020-sarkari-naukri-driver-bharti-govt-job-alert-lbs-1-1185328.html
# data not found
# https://aajtak.intoday.in//education/story/hsl-recruitment-2020-sarkari-naukri-driver-bharti-govt-job-alert-lbs-1-1185328.html
# data not found
# https://aajtak.intoday.in//women
# https://aajtak.intoday.in//women
# https://aajtak.intoday.in//story/aajtak-eagenda-raambaan-se-bhagega-corona-baba-ramdev-said-people-shoud-avoid-bad-habbits-during-diets-tlif-1-1184399.html
# https://aajtak.intoday.in//story/e-agenda-aaj-tak-baba-ramdev-suggests-healthy-diet-ram-baan-se-bhagega-corona-tlif-1-1184359.html
# https://aajtak.intoday.in//story/sabyasachi-mukherjee-how-spends-time-at-home-during-lockdown-tlif-1-1182924.html
# https://aajtak.intoday.in//story/india-today-e-conclave-designer-sabyasachi-mukherjee-on-post-coronavirus-fashion-tlif-1-1182908.html
# https://aajtak.intoday.in//dilliaajtak
# https://aajtak.intoday.in//dilliaajtak
# https://aajtak.intoday.in//delhi/video/babu-jagjeevan-ram-hospital-closed-after-health-workers-tests-positive-for-covid-19-1-1185395.html
# https://aajtak.intoday.in//delhi/video/delhi-chilla-gaon-people-arranges-food-for-poor-amid-lockdown-due-to-coronavirus-1-1185171.html
# data not found
# https://aajtak.intoday.in//delhi/video/delhi-adarsh-nagar-majlis-park-area-lnjp-hospital-lady-dietitian-and-her-family-corona-positive-1-1185164.html
# data not found
# https://aajtak.intoday.in//delhi/video/delhi-haryana-border-sealed-to-stop-coronavirus-spread-watch-ground-report-1-1185156.html
# https://aajtak.intoday.in//tez
# https://aajtak.intoday.in//tez
# https://aajtak.intoday.in//tez/video/viral-sach-fact-check-viral-video-of-delhi-govt-serving-stale-food-duing-lockdown-fake-ramesh-bhiduri-delhi-news-in-hindi-1-1185413.html
# https://aajtak.intoday.in//tez/video/viral-sach-fact-check-viral-video-of-delhi-govt-serving-stale-food-duing-lockdown-fake-ramesh-bhiduri-delhi-news-in-hindi-1-1185413.html
# https://aajtak.intoday.in//tez/video/know-all-big-and-important-updates-of-covid-19-here-1-1185401.html
# https://aajtak.intoday.in//tez/video/know-all-big-and-important-updates-of-covid-19-here-1-1185401.html
# https://aajtak.intoday.in//karyakram/video/chaal-chakra-how-to-make-your-marriage-relationship-stronger-astrology-astro-shows-1-1185330.html
# https://aajtak.intoday.in//karyakram/video/chaal-chakra-how-to-make-your-marriage-relationship-stronger-astrology-astro-shows-1-1185330.html
# https://aajtak.intoday.in//tez/video/wedding-bells-during-coronavirus-lockdown-seven-stories-of-couple-who-tied-nuptial-knot-1-1185161.html
# https://aajtak.intoday.in//tez/video/wedding-bells-during-coronavirus-lockdown-seven-stories-of-couple-who-tied-nuptial-knot-1-1185161.html
# https://aajtak.intoday.in//complain_redressal.php
# data not found
# https://aajtak.intoday.in//investor
# https://aajtak.intoday.in//partners.php
# https://aajtak.intoday.in//prnewswire/prnewswire.html
# https://aajtak.intoday.in//livetv.html
# https://aajtak.intoday.in//news.html
# https://aajtak.intoday.in//states-news.html
# https://aajtak.intoday.in//sports/
# https://aajtak.intoday.in//career.html
# https://aajtak.intoday.in//women/
# https://aajtak.intoday.in//photos.html
# https://aajtak.intoday.in//videos.html
# https://aajtak.intoday.in//movie-masala.html
# https://aajtak.intoday.in//tech/
# https://aajtak.intoday.in//crime/
# https://aajtak.intoday.in//dharam/
# https://aajtak.intoday.in//karyakrams.html
# https://aajtak.intoday.in//calender.php
# https://aajtak.intoday.in//investor
# https://aajtak.intoday.in//story/breaking-news-1-59000.html
# data not found
# https://aajtak.intoday.in//khabare-ab-tak.html
# https://aajtak.intoday.in//rssfeeds/?feed=rss1.0&no_html=1&rsspage=home
# https://aajtak.intoday.in//distribution/rio/
# data not found
# https://aajtak.intoday.in//tvtmi
# https://aajtak.intoday.in/ https://www.headlinestoday.in/
# data not found

# %%
dataset=pd.DataFrame(df)
from google.colab import files
# Out:
# (448, 5)

# %%
print(dataset.shape)
D = dataset
print(D.shape)
D.drop([1])
print(D.shape)
# Out:
# (140, 5)
# (140, 5)
# (140, 5)

# %%
for i in range(dataset.shape[0]):
  try:
    if(dataset.iloc[i,2] == 0 ):
      print("YES")
      if( dataset.iloc[i,3] == 0):
        print("YESS")
        if (dataset.iloc[i,4] == 0):
          print("YESSS")
          dataset = dataset.drop(i,axis = 0)
  except:
   continue
dataset.to_csv('df.csv')
files.download('df.csv')
# Out:
# YES
# YESS
# YES
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YES
# YESS
# YES
# YESS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# YES
# YESS
# YESSS
# (115, 5)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
FILEPATH = "OnlineNewsPopularity.csv" 
def clean_cols(data):
    """Clean the column names by stripping and lowercase."""
    clean_col_map = {x: x.lower().strip() for x in list(data)}
    return data.rename(index=str, columns=clean_col_map)

def TrainTestSplit(X, Y, R=0, test_size=0.2):
    """Easy Train Test Split call."""
    return train_test_split(X, Y, test_size=test_size, random_state=R)

full_data = clean_cols(pd.read_csv(FILEPATH))
train_set, test_set = train_test_split(full_data, test_size=0.20, random_state=42)

x_train = train_set.drop(['url','shares', 'timedelta', 'lda_00','lda_01','lda_02','lda_03','lda_04','num_self_hrefs', 'kw_min_min', 'kw_max_min', 'kw_avg_min','kw_min_max','kw_max_max','kw_avg_max','kw_min_avg','kw_max_avg','kw_avg_avg','self_reference_min_shares','self_reference_max_shares','self_reference_avg_sharess','rate_positive_words','rate_negative_words','abs_title_subjectivity','abs_title_sentiment_polarity'], axis=1)
y_train = train_set['shares']

x_test = test_set.drop(['url','shares', 'timedelta', 'num_self_hrefs', 'kw_min_min', 'kw_max_min', 'kw_avg_min','kw_min_max','kw_max_max','kw_avg_max','kw_min_avg','kw_max_avg','kw_avg_avg','self_reference_min_shares','self_reference_max_shares','self_reference_avg_sharess','rate_positive_words','rate_negative_words','abs_title_subjectivity','abs_title_sentiment_polarity'], axis=1)
y_test = test_set['shares']




clf = RandomForestRegressor(random_state=42)
clf.fit(x_train, y_train)


rf_res = pd.DataFrame(clf.predict(x_train),list(y_train))
rf_res.reset_index(level=0, inplace=True)
rf_res_df = rf_res.rename(index=str, columns={"index": "Actual shares", 0: "Predicted shares"})
rf_res_df.head()

# %%
'''

The Web Scrapping Part is Completely Done 100% and same was the model training part.
But due to some technical issues, I was not able to give the " prestige ", the final act to this project.
Still I have noted below the steps needed t be taken after training the model, also the reference code for the same is continued below.

Step 1:  Convert our Dataset and make it similar to the predefined UCI Dataset.
        Add All the columns
        Compute All the Values
        Assume if necessary
Step 2:   Test the model with our dataset as input

This is not a big part of the code, but I understand it is very important part of the code.

Thank You !

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
stopwords=set(stopwords.words('english'))

def rate_unique(words):
    words=tokenize(words)
    no_order = list(set(words))
    rate_unique=len(no_order)/len(words)
    return rate_unique


def rate_nonstop(words):
    words=tokenize(words)
    filtered_sentence = [w for w in words if not w in stopwords]
    rate_nonstop=len(filtered_sentence)/len(words)
    no_order = list(set(filtered_sentence))
    rate_unique_nonstop=len(no_order)/len(words)
    return rate_nonstop,rate_unique_nonstop


def avg_token(words):
    words=tokenize(words)
    length=[]
    for i in words:
        length.append(len(i))
    return np.average(length)

from textblob import TextBlob

import datefinder
import datetime  
from datetime import date 
def day(article_text):
    article=article_text
    if len(list(datefinder.find_dates(article)))>0:
        date=str(list(datefinder.find_dates(article))[0])
        date=date.split()
        date=date[0]
        year, month, day = date.split('-')     
        day_name = datetime.date(int(year), int(month), int(day)) 
        return day_name.strftime("%A")
    return "Monday"

def tokenize(text):
    text=text
    return word_tokenize(text)

pos_words=[]
neg_words=[]
def polar(words):
    all_tokens=tokenize(words)
    for i in all_tokens:
        analysis=TextBlob(i)
        polarity=analysis.sentiment.polarity
        if polarity>0:
            pos_words.append(i)
        if polarity<0:
            neg_words.append(i)
    return pos_words,neg_words

def rates(words):
    words=polar(words)
    pos=words[0]
    neg=words[1]
    all_words=words
    global_rate_positive_words=(len(pos)/len(all_words))/100
    global_rate_negative_words=(len(neg)/len(all_words))/100
    pol_pos=[]
    pol_neg=[]
    for i in pos:
        analysis=TextBlob(i)
        pol_pos.append(analysis.sentiment.polarity)
        avg_positive_polarity=analysis.sentiment.polarity
    for j in neg:
        analysis2=TextBlob(j)
        pol_neg.append(analysis2.sentiment.polarity)
        avg_negative_polarity=analysis2.sentiment.polarity
    min_positive_polarity=min(pol_pos)
    max_positive_polarity=max(pol_pos)
    min_negative_polarity=min(pol_neg)
    max_negative_polarity=max(pol_neg)
    avg_positive_polarity=np.average(pol_pos)
    avg_negative_polarity=np.average(pol_neg)
    return global_rate_positive_words,global_rate_negative_words,avg_positive_polarity,min_positive_polarity,max_positive_polarity,avg_negative_polarity,min_negative_polarity,max_negative_polarity

# %%
df2=[]
for i in news:
    pred_info={}
    article = Article(i, language="en") # en for English 
    article.download() 
    article.parse()
    analysis=TextBlob(article.text)
    polarity=analysis.sentiment.polarity
    title_analysis=TextBlob(article.title)
    pred_info['text']=article.text
    pred_info['n_tokens_title']=len(tokenize(article.title))
    pred_info['n_tokens_content']=len(tokenize(article.text))
    pred_info['n_unique_tokens']=rate_unique(article.text)
    pred_info['n_non_stop_words']=rate_nonstop(article.text)[0]
    pred_info['n_non_stop_unique_tokens']=rate_nonstop(article.text)[1]
    pred_info['num_hrefs']=article.html.count("https://timesofindia.indiatimes.com")
    pred_info['num_imgs']=len(article.images)
    pred_info['num_videos']=len(article.movies)
    pred_info['average_token_length']=avg_token(article.text)
    pred_info['num_keywords']=len(article.keywords)
    
    if "life-style" in article.url:
        pred_info['data_channel_is_lifestyle']=1
    else:
        pred_info['data_channel_is_lifestyle']=0
    if "etimes" in article.url:
        pred_info['data_channel_is_entertainment']=1
    else:
        pred_info['data_channel_is_entertainment']=0
    if "business" in article.url:
        pred_info['data_channel_is_bus']=1
    else:
        pred_info['data_channel_is_bus']=0
    if "social media" or "facebook" or "whatsapp" in article.text.lower():
        data_channel_is_socmed=1
        data_channel_is_tech=0
        data_channel_is_world=0
    else:
        data_channel_is_socmed=0
    if ("technology" or "tech" in article.text.lower()) or ("technology" or "tech" in article.url):
        data_channel_is_tech=1
        data_channel_is_socmed=0
        data_channel_is_world=0
    else:
        data_channel_is_tech=0
    if "world" in article.url:
        data_channel_is_world=1
        data_channel_is_tech=0
        data_channel_is_socmed=0
    else:
        data_channel_is_world=0
        
    pred_info['data_channel_is_socmed']=data_channel_is_socmed
    pred_info['data_channel_is_tech']=data_channel_is_tech
    pred_info['data_channel_is_world']=data_channel_is_world
    
    if day(i)=="Monday":
        pred_info['weekday_is_monday']=1
    else:
        pred_info['weekday_is_monday']=0
    if day(i)=="Tuesday":
        pred_info['weekday_is_tuesday']=1
    else:
        pred_info['weekday_is_tuesday']=0
    if day(i)=="Wednesday":
        pred_info['weekday_is_wednesday']=1
    else:
        pred_info['weekday_is_wednesday']=0
    if day(i)=="Thursday":
        pred_info['weekday_is_thursday']=1
    else:
        pred_info['weekday_is_thursday']=0
    if day(i)=="Friday":
        pred_info['weekday_is_friday']=1
    else:
        pred_info['weekday_is_friday']=0
    if day(i)=="Saturday":
        pred_info['weekday_is_saturday']=1
        pred_info['is_weekend']=1
    else:
        pred_info['weekday_is_saturday']=0
    if day(i)=="Sunday":
        pred_info['weekday_is_sunday']=1
        pred_info['is_weekend']=1
    else:
        pred_info['weekday_is_sunday']=0
        pred_info['is_weekend']=0
        
    pred_info['global_subjectivity']=analysis.sentiment.subjectivity
    pred_info['global_sentiment_polarity']=analysis.sentiment.polarity
    pred_info['global_rate_positive_words']=rates(article.text)[0]
    pred_info['global_rate_negative_words']=rates(article.text)[1]
    pred_info['avg_positive_polarity']=rates(article.text)[2]
    pred_info['min_positive_polarity']=rates(article.text)[3]
    pred_info['max_positive_polarity']=rates(article.text)[4]
    pred_info['avg_negative_polarity']=rates(article.text)[5]
    pred_info['min_negative_polarity']=rates(article.text)[6]
    pred_info['max_negative_polarity']=rates(article.text)[7]    
    pred_info['title_subjectivity']=title_analysis.sentiment.subjectivity
    pred_info['title_sentiment_polarity']=title_analysis.sentiment.polarity
    df2.append(pred_info)

# %%
pred_df=pd.DataFrame(df2)
pred_test=pred_df.drop(['text'],axis=1)
pred_df.head()

# %%
test2=pd.DataFrame(clf.predict(pred_test),pred_df['text'])
test2.reset_index(level=0, inplace=True)
test2 = test2.rename(index=str, columns={"index": "News", 0: "Virality"})
test2
